# %% [markdown]
# # Loading Libraries and API Package

# %%
from tmdbv3api import TMDb
from tmdbv3api import Movie
from tmdbv3api import TV
from tmdbv3api import Genre, Search

tmdb = TMDb()
tmdb.api_key = '3645538d59141adac64aaa49b3cb02f7'
tmdb.language = 'en'
tmdb.debug = True


movie = Movie()
tv = TV()
genre = Genre()

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
import matplotlib.pyplot as plt
import json as json
import pickle
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

# %matplotlib inline

# %% [markdown]
# # Loading STC JAWWY Data

# %%
stc = pd.read_csv('/Users/mo/Desktop/Desktop/School/Online Courses/Udacity/Data Scientist/Final /Final_Dataset.txt', delimiter = ",")
stc = stc.drop('Unnamed: 0', axis=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/sn/7klq0gls5qz987z3jr52_jym0000gn/T/ipykernel_3134/3861073865.py in <module>
# ----> 1 stc = pd.read_csv('/Users/mo/Desktop/Desktop/School/Online Courses/Udacity/Data Scientist/Final /Final_Dataset.txt', delimiter = ",")
#       2 stc = stc.drop('Unnamed: 0', axis=1)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/mo/Desktop/Desktop/School/Online Courses/Udacity/Data Scientist/Final /Final_Dataset.txt'

# %%
# creating unique id for videos
df = stc.copy()
df['vid_id'] = df.groupby(['original_name']).ngroup()
df.head()

# %%
df['original_name'] = [" ".join(x.split()) for x in df['original_name']]

# %%
# get the names of TVs and movies
movie_orig = list(set(df[df['program_class'] == 'MOVIE']['original_name']))
tv_orig = list(set(df[df['program_class'] != 'MOVIE']['original_name']))

# %%
print("Number of TV Shows {}".format(len(tv_orig)))
print("Number of Movies {}".format(len(movie_orig)))
# Out:
# Number of TV Shows 276
# Number of Movies 1525

# %%
list(set(df['original_name']))
# Out:
# ['The Big Year',
#  'Frankie & Alice',
#  'Northern oul',
#  'Digswell',
#  'Paul Blart: Mall Cop',
#  "Lemony nicket's Unfortunate Events",
#  'Penny Dreadful',
#  'The Black Envelope (T)',
#  'Painkiller Jane',
#  'Scooby-Doo! The WrestleMania Mystery',
#  'Ghost in the hell',
#  'Le Divorce',
#  'The Other Guys',
#  'The Fifth Estate',
#  'Tell',
#  'Arena of the treet Fighter',
#  'The Legend Of Zorro',
#  'Splash',
#  'Men at Work',
#  'Kung Fu tyle',
#  'Breaking Bad',
#  'Horton Hears a Who!',
#  'Puss in Boots',
#  'Star Trek',
#  'Mars Attacks!',
#  'Slow West',
#  'Crazy tupid Love',
#  'Paper Towns',
#  'Twelve Monkeys',
#  'Mars Needs Moms',
#  'Logan',
#  'Se7en',
#  'Monsters: Dark Continent',
#  'The elfish Giant',
#  'Wolf Totem',
#  'Date Night',
#  'XIII: The eries',
#  'Oliver and Company',
#  'Aloft',
#  'Mr. Robot',
#  'Aloha',
#  'Sucker Punch',
#  'Pinocchio',
#  'Baggage Claim',
#  'Premium Rush',
#  'Game of Aces',
#  'The Killer peaks',
#  'The Naked Gun ½: The mell of Fear',
#  'Rogue',
#  'Milly Molly',
#  'Mr. & Mrs. mith',
#  'Afrah Al Qibba',
#  'Just Wright',
#  'Intruders',
#  '2012',
#  'Morning Glory',
#  'Payback',
#  'Face Off',
#  'Cast Away',
#  'Extraterrestrial',
#  'The Dinner',
#  'Housebound',
#  'Empire',
#  'Spider-Man: Homecoming',
#  'Guess Who',
#  'Oz: The Great and Powerful',
#  'An Officer and a Gentleman',
#  'Tangled',
#  'Bedtime tories',
#  'Free Fire',
#  'Broken Vows',
#  'Pirates of the Caribbean: Dead Men Tell...',
#  'Cop Out',
#  'The Heartbreak Kid',
#  'Being Flynn',
#  'Legends Of Tomorrow',
#  'The Trip to Italy',
#  'Star Trek VI: The Undiscovered Country',
#  'Transcendence',
#  'Constantine',
#  'Cradle To The Grave',
#  'Sweet Home Alabama',
#  'Our Kind Of Traitor',
#  'I Am Legend',
#  'The entinel',
#  'Fatal Attraction',
#  'Elektra',
#  'Haret Al Yahud',
#  'Shades Of Blue',
#  'The Exorcism Of Emily Rose',
#  "Tim Burton's Corpse Bride",
#  'Sleepless',
#  'The Little Vampire',
#  'Into the torm',
#  'Inspector Gadget',
#  'Cats and Dogs',
#  'The League of Extraordinary Gentlemen',
#  'Rambler',
#  'The anta Clause',
#  'Rogue One: A tar Wars tory',
#  'Deep Impact',
#  'Tawq A-Najat',
#  'Cinderella',
#  'Clown',
#  'Run for Your Wife',
#  'Six',
#  'Gravity',
#  'Pride and Prejudice and Zombies',
#  "Stan Lee's uperhumans",
#  'Qabel Lel Kaser (T)',
#  'Transporter',
#  'The Woman in the Fifth',
#  'My Cousin Rachel',
#  'Fantastic : Rise of the ilver urfer',
#  'The Rewrite',
#  'Wilson',
#  'Doctor Dolittle',
#  'First Kiss',
#  'Mississippi Grind',
#  'Banat okkar Nabat (T)',
#  'G.I. Joe: The Rise Of Cobra',
#  'The Penguins of Madagascar',
#  'When in Rome',
#  'Star Trek IV: The Voyage Home',
#  'Friday the th: The Final Chapter',
#  'Mortdecai',
#  'The Mermaid Princess',
#  'House',
#  'Phone Booth',
#  'Metro Manila',
#  'How To Train Your Dragon',
#  'Hall Pass',
#  'Jane Eyre',
#  'This Means War',
#  'The Greatest howman',
#  'Hal Manayer (T)',
#  'Default',
#  'Sonic Underground',
#  'The Princess and the Frog',
#  'Due Date',
#  'Dom Hemingway',
#  'Alvin and the Chipmunks',
#  'The Boy Next Door',
#  'Lego cooby-Doo! Blowout Beach Bash',
#  'Days of Thunder',
#  'Hemlock Grove',
#  'I Am Not a erial Killer',
#  'Agent Carter',
#  "Piglet's Big Movie",
#  'The keptic',
#  'Unbreakable',
#  "Grey's Anatomy",
#  'Mumuhug',
#  'A Goofy Movie',
#  'Testament of Youth',
#  'Rabbit chool: Guardians of the Golden Egg',
#  "Winter's Tale",
#  'Once Upon A Time (T)',
#  'A Thousand Words',
#  'DCU: on of Batman',
#  'Maze Runner: The Death Cure',
#  'Tom awyer & Huckleberry Finn',
#  'Enchanted',
#  'Kalam A-Nas',
#  'Shooter',
#  'First Kill',
#  'Turner and Hooch',
#  'Pineapple Express',
#  'Hammer of the Gods',
#  'Smurfs: The Lost Village',
#  'A Lobster Tale',
#  'Lucky Them',
#  'The Raid: Redemption',
#  'Burnt',
#  'iCarly',
#  'Ray',
#  'King Arthur: Legend of the word',
#  "Pete's Dragon",
#  'Montana',
#  'Maleficent',
#  'Harry Potter Part (1)',
#  'American Honey',
#  "Big Momma's House",
#  'Heavenly word',
#  'The First Wives Club',
#  'The Pacifier',
#  'Automata',
#  'Bloodline',
#  'Lego DC uper Hero Girls: Brain Drain',
#  'Garfield',
#  'Triple Nine',
#  'World Trade Centre',
#  'Arsenal',
#  'Phoenix Forgotten',
#  'Love Me till',
#  'Independence Daysaster',
#  'How I Live Now',
#  'Friday After Next',
#  'Dora the Explorer',
#  '500 Days of ummer',
#  'Blended',
#  'Some Velvet Morning',
#  'Wall E',
#  'Stardust',
#  'Damages',
#  'Anchorman : The Legend Continues',
#  'DC uper Hero Girls: Intergalactic Games',
#  'Zakera Mn Waraq (T)',
#  'Morgan',
#  'The impsons Movie',
#  'The Notebook',
#  'Scandal',
#  'Killing Gunther',
#  'Yamal A-Sham Ep',
#  'Ghost In The hell: Laughing Man',
#  'Hancock',
#  'Star Trek: The Motion Picture',
#  'The Accused',
#  'The Americans',
#  'The Wild Thornberrys Movie',
#  'Life After Beth',
#  'Superman III',
#  'The Wild',
#  'Lost',
#  'Gifted',
#  'The Bucket List',
#  'The Raid',
#  'Devil May Call',
#  'Born Of War',
#  'Rugrats Go Wild',
#  '300',
#  "Ocean's Twelve",
#  'Extremely Loud and Incredibly Close',
#  'The Jungle Book',
#  'Kung Fu Panda',
#  'The November Man',
#  'Harry Potter Part',
#  'Salt',
#  'Machete Kills',
#  'Gran Torino',
#  'Ghost Rider',
#  '30 Minutes Or Less',
#  'Ninja Assassin',
#  'The Chronicles of Riddick',
#  'Good Morning Vietnam',
#  'Crazy Heart',
#  'Partisan',
#  'The Woman in Black: Angel of Death',
#  'Inside',
#  'Tears of The un',
#  'The Howling Reborn',
#  'Lonely treet',
#  'Final Cut',
#  'The Flash',
#  'Rise of the Planet of the Apes',
#  'Masters of Horror',
#  'Signs',
#  'Office Christmas Party',
#  'The Matrix',
#  'Slugterra',
#  'Swiss Army Man',
#  'The Dukes Of Hazzard',
#  'Street Dance All tars',
#  'Donnie Brasco',
#  'Entrapment',
#  'SpongeBob quarePants',
#  'The Dead : India',
#  'The Cable Guy',
#  'The Distinguished Gentleman',
#  'Nightmare On Elm treet',
#  'Star Trek V: The Final Frontier',
#  'Cars',
#  'The Intervention',
#  'Flatliners',
#  'Forces of Nature',
#  'xXx',
#  'American Horror tory',
#  'Fireman am',
#  '22 Jump treet',
#  'Blue treak',
#  'Labor Day',
#  'Along Came Polly',
#  'Surfer Dude',
#  'The Finest Hours',
#  'Oculus',
#  "White Men Can't Jump",
#  'Almost Famous',
#  'Aftermath',
#  'Tulip Fever',
#  "Jennifer's Body",
#  'Bo on the Go (T)',
#  'The Big hort',
#  'Vikings',
#  'House of Lies',
#  "Al Akhwa A'adaa (T)",
#  'Escape Room',
#  'Madagascar',
#  'Blood Diamond',
#  'Mr. Deeds',
#  'Underworld: Awakening',
#  '100 treets',
#  'The Legend of Tarzan',
#  'Teletubbies',
#  'Knightfall',
#  'Behind Enemy Lines : Colombia',
#  'An Inconvenient equel: Truth to Power',
#  'Youm Maloosh Lazma',
#  'Badges of Fury',
#  'A Glimpse Inside the Mind of Charles',
#  'Backtrack',
#  'Hidalgo',
#  'Swordfish',
#  "Scooby Doo! haggy's howdown",
#  'Boychoir',
#  'Judge Dredd',
#  'Brother Nature',
#  'The Adventures of Petey and Friends',
#  'The Orphan',
#  'Red Dragon',
#  'If I tay',
#  'U.S. Marshals',
#  'Homeland',
#  'Storks',
#  'Rubbadubbers',
#  'Oswald',
#  'Midnight pecial',
#  'Hereafter',
#  'The Walking Dead',
#  'Saving Mr. Banks',
#  'Paper Planes',
#  'Unfaithful',
#  'Fee Amal (T)',
#  'Monsters Vs. Aliens',
#  'Savages',
#  'Little Red',
#  'Failure to Launch',
#  'A Very Harold And Kumar Christmas',
#  'Zay Al Ward - Ep',
#  'Batman Returns',
#  'Sehhee Wa aree',
#  'The Revenant',
#  'Another Hrs',
#  'Romeo Must Die',
#  'Four Brothers',
#  'The Drop',
#  'Al Hob Allathi Kan',
#  'Cellular',
#  'Made Of Honor',
#  'Hellboy',
#  'Spirit: tallion of the Cimarron',
#  'The Raven',
#  "Legends of Oz: Dorothy's Return",
#  "Recess: chool's Out",
#  'Kristy',
#  "What's Your Number?",
#  '24',
#  'Morris from America',
#  'Top Five',
#  "Survivor's Remorse",
#  'Devious Maids',
#  'The Void',
#  'Final Fantasy VII: Advent Children',
#  'Deja Vu',
#  'The Day After Tomorrow',
#  'Always hine',
#  'House Of Wax',
#  'Diary of a Wimpy Kid: The Long Haul',
#  'Hello Carter',
#  'The pongeBob Movie: ponge Out of Water',
#  'White House Down',
#  'The Uninvited',
#  'Escape from the Planet of the Apes',
#  'Nine',
#  'Insidious: Chapter',
#  'The Karate Kid',
#  'The Golden Compass',
#  'Weeds (T)',
#  'Welada Min Al Khasira -Ep',
#  'The Flowers Of War',
#  "Surf's Up : WaveMania",
#  'Adulthood',
#  'Star Trek III: The earch for pock',
#  '300: Rise of an Empire',
#  'Aliens vs. Predator: Requiem',
#  '17 Again',
#  'Contagion',
#  '102 Dalmatians',
#  'Dolphin Tale',
#  'Solace',
#  'Billions',
#  'It Follows',
#  'My uper Ex-Girlfriend',
#  'Journey to the Center of the Earth',
#  'The Pirates! Band Of Misfits',
#  'Fight Club',
#  'Glory Road',
#  'Eight Below',
#  'What Happened Last Night',
#  'Django Unchained',
#  'Megamind',
#  'Men at Work (T)',
#  'The Door',
#  'Piranha DD',
#  'Marauders',
#  'Harry Potter and the Goblet of Fire Part',
#  "Pirates of The Caribbean: Dead Man's Ches",
#  'Parker',
#  'Inferno',
#  'Melissa & Joey',
#  'The Descendants',
#  'Maze Runner: The corch Trials',
#  'Blank Check',
#  'Unfinished Business',
#  'Sleight',
#  'Big Miracle',
#  'Emoji Movie',
#  'Elvis & Nixon',
#  'Avengers Confidential: Black Widow',
#  'Tomorrowland',
#  'Aquarius',
#  'The Boss Baby',
#  'Renaissance Man',
#  'George of the Jungle',
#  'Vampires uck',
#  'Indama Yuzher Al Khareef',
#  'Rosewater',
#  'The Incredibles',
#  'The Holiday',
#  'The Lovers',
#  'Bambi',
#  'Teddy Bear',
#  'War for the Planet of the Apes',
#  'Monsters University',
#  'Beavis And Butt-Head Do America',
#  'Animal Mechanicals',
#  'Run All Night',
#  '11.6',
#  'Lost ignal',
#  'Blaze And The Monster Machines',
#  'Alaameel',
#  'Over the Hedge',
#  'Ya Reit',
#  'Blessed',
#  'Albert Asks',
#  'Omena Rowehet El Janna',
#  'The Chronicles Of Narnia: Prince Caspian',
#  'The Muppet Christmas Carol',
#  'X + Y',
#  "The Hitchhiker's Guide To The Galaxy",
#  'American Psycho',
#  'Wolves At The Door',
#  "Can't Buy Me Love",
#  'Planet of the Apes',
#  'The Matrix Revolution',
#  'Close Encounters of the Third Kind',
#  'Friends with Benefits',
#  'Extant (T)',
#  'Kill Zone',
#  'American niper',
#  'Oblivion',
#  'Despite the Falling now',
#  'Obsessed',
#  'The Hunted',
#  'Witness',
#  'Al Kasr Al Kabeer',
#  'Jackass D',
#  'The X Files: I Want to Believe',
#  'Vigilante Diaries',
#  'Fantastic Four',
#  'Snow Day',
#  'Burn Country',
#  '2 Fil-Isaaf (T)',
#  'Billy Lynn’s Long Halftime Walk',
#  'Al Maaa',
#  'Jupiter Ascending',
#  'Red Dawn',
#  'Teenage Mutant Ninja Turtles',
#  "She's Out of My League",
#  'Allied',
#  'Changing Lanes',
#  'Syriana',
#  'McFarland USA',
#  'The X Files',
#  'Ghost in the hell: tand Alone Complex (T)',
#  'Raven the Little Rascal - The Big Race',
#  'Enemy of the tate',
#  'Analyze That',
#  'J. Edgar',
#  'Butter',
#  'Certain Women',
#  'The Incredible tory of tone Boy',
#  'The Man with the Iron Heart',
#  'The Inbetweeners',
#  'Beverly Hills Chihuahua',
#  'The Manchurian Candidate',
#  'War Of The Worlds',
#  'Hard Eight',
#  'The Mask Of Zorro',
#  'The piderwick Chronicles',
#  'Friday The Th Part VI',
#  'Pinky Dinky Doo',
#  'Kill Command',
#  'Pride and Glory',
#  'Up',
#  'Walking with Dinosaurs',
#  'Open Windows',
#  'Talladega Nights: Ballad Of Ricky Bobby',
#  'Harold & Kumar Escape From Guantanamo Bay',
#  'Drive Angry',
#  'Hitch',
#  'Min Qesas As-Saliheen',
#  'Young Adult',
#  'Bad Teacher',
#  'Crossing Over',
#  'The BFG',
#  'In The Blood',
#  'Blow',
#  'Dough Boys',
#  'The Heat',
#  'The Tale of Princess Kaguya',
#  'Parental Guidance',
#  'Identity',
#  'Secret Window',
#  'Escobar: Paradise Lost',
#  'Martyrs',
#  'Road To Paloma',
#  'Austin Powers: The py Who hagged Me',
#  'Bubble Guppies',
#  'The Hobbit: The Desolation Of maug',
#  'MoniKa',
#  'Up in the Air',
#  'Jack Reed: A earch for Justice',
#  'The um Of All Fears',
#  "A Dog's Purpose",
#  'Men of Honor',
#  'National Treasure',
#  'Franklin and Bash',
#  'Thor: Ragnarok',
#  'John Q',
#  'Hotel Transylvania',
#  'Penguins of Madagascar',
#  'Despicable Me',
#  "Every Woman's Dream",
#  'Harry Potter Part (2)',
#  'Moon',
#  'Barnyard',
#  'Coco',
#  'The uicide hop',
#  'Tropic Thunder',
#  'We Bought a Zoo',
#  'Angels and Demons',
#  'The Monster',
#  'High Rise',
#  'Going The Distance',
#  'Robot Overlords',
#  'The Day the Earth tood till',
#  'Dora The Explorer',
#  'Inside Out',
#  'Youth in Revolt',
#  'Friends',
#  'Our Cartoon President',
#  'The Neighbor',
#  'Falcon Rising',
#  'The Patriot',
#  'How I Met Your Mother',
#  'No Tell Motel',
#  'Forrest Gump',
#  'Siret Hob',
#  'Babylon A.D.',
#  "There's omething About Mary",
#  'Scandal (T)',
#  'Tracers',
#  'Female Agents/Unusual Heroes',
#  'Patriot Games',
#  'At Any Price',
#  '48 Hrs',
#  'Naked Gun /3: The Final Insult',
#  'Bob Al-Banaa',
#  'Daddy Day Camp',
#  'Rollerball',
#  'Mulan',
#  'Marmaduke',
#  'Life',
#  'Aftershock',
#  'Robots',
#  'Conquest of the Planet of the Apes',
#  'Crimson Tide',
#  'Jungle Master : Candy Planet',
#  'Bionicle : The Legend Reborn',
#  'American Reunion',
#  'Inside Man',
#  'Snow White and the Huntsman',
#  'The Odd Life of Timothy Green',
#  'Gone Girl',
#  'Old chool',
#  'Robin Hood',
#  'The Internship',
#  'Ghost In The hell: Individual Eleven',
#  'One Missed Call',
#  'Lady and the Tramp',
#  'The Flash (T)',
#  'Boule & Bill',
#  'Kickboxer',
#  'The Lovely Bones',
#  'Poltergeist',
#  'Sabrina The Animated eries (T)',
#  'The Chronicles Of Narnia: Part',
#  'Around The Block',
#  'Synchronicity',
#  'Teen Wolf',
#  '12 Rounds',
#  "Snow White's New Adventure",
#  'Mad Love',
#  'The Muppet Movie',
#  "Madagascar : Europe's Most Wanted",
#  'Desert Dancer',
#  "The Emperor's New Groove",
#  'The Lookalike',
#  'Antibirth',
#  'The American ide',
#  'Friday The th',
#  'The Negotiator',
#  'Closer',
#  'Batman',
#  'Bringing Down the House',
#  'Al Hasharat Al agheerah EP2',
#  'The Curious Case Of Benjamin Button',
#  'The Rite',
#  'Unstoppable',
#  'Ash vs Evil Dead',
#  'Wonder Woman: Commemorative Edition',
#  'Mean Girls',
#  'Why Him',
#  'Supergirl',
#  'Anna Karenina',
#  'St. Vincent',
#  'Legend of the Guardians',
#  'Ultraviolet',
#  'Mirrors',
#  'Transformers: Age of Extinction',
#  'Reign of Fire',
#  'The hape of Water',
#  'Secretariat',
#  'Halt And Catch Fire',
#  'Top Tables Top Cities',
#  'Long Weekend',
#  'The White Queen',
#  'Staying Alive',
#  'The Lord of the Rings Part',
#  'Miss You Already',
#  'Jurassic Park',
#  'Alhara (T)',
#  'Unlocked',
#  'The Whisperers',
#  'Zoolander',
#  'Argo',
#  'Marcus Level (T)',
#  'The Informant!',
#  'John Wick',
#  'Are We Done Yet?',
#  'Queen of the Desert',
#  'The Lone Ranger',
#  'Grudge Match',
#  'Prince of Persia: The ands of Time',
#  'Ward Jouri (T)',
#  'Die Hard',
#  '4 Minute Mile',
#  '12 Monkeys',
#  'The Weather Man',
#  'The Babadook',
#  'In the Night Garden',
#  'Stealth',
#  'The Hunger Games: Mockingjay - Part',
#  'The Circle',
#  'SMILF',
#  'Empire tate',
#  'Red Riding Hood',
#  'Scouts Honor',
#  'Alvin and the Chipmunks: The Road Chip',
#  'Joy',
#  'Alexander and the Terrible Horrible No Good Bad Day',
#  'Shrek Forever After',
#  'The Equalizer',
#  '24 Hours to Live',
#  'Rise of the Guardians',
#  'Grabbers',
#  'When The Bough Breaks',
#  'Wreck-It Ralph',
#  'Mark Felt',
#  'Please tand By',
#  'The White Princess',
#  'Born in China',
#  'Diary of a Wimpy Kid',
#  'Ice Age: Dawn of the Dinosaurs',
#  'Justice League Dark',
#  'War Dogs',
#  'Cruel Intentions',
#  'All Things Must Pass',
#  'Vice',
#  'Batman Begins',
#  'Greetings From Tim Buckley',
#  'Nitro Circus: The Movie',
#  'A Good Day to Die Hard',
#  'Knight and Day',
#  'Battle for the Planet of the Apes',
#  "A Knight's Tale",
#  'The Windmill Massacre',
#  'Friday the th Part VII: The New Blood',
#  'The Girl on the Train',
#  'Harry',
#  'The Firm',
#  'The Making of the Mob: New York',
#  'Captain Phillips',
#  'Flushed Away',
#  'The Greatest Game Ever Played',
#  'ParaNorman',
#  'Million Dollar Arm',
#  'Hyde Park On Hudson',
#  'Norbit',
#  "Beethoven's Treasure Tail",
#  'Black-ish (T)',
#  'Dinosaur',
#  'Extant',
#  'We Need to Talk About Kevin',
#  'National ecurity',
#  'Ice Princess',
#  'Night at the Museum: ecret of the Tomb',
#  'Cheaper by the Dozen',
#  'Annabelle: Creation',
#  'Al Hala G',
#  'From Paris With Love',
#  'Magic City',
#  'Justified',
#  'Once Upon A Time In Mexico',
#  'Sea of Trees',
#  'Beverly Hills Cop',
#  'Honey I Blew Up the Kid',
#  'The Curse of the Were-Rabbit',
#  "It's Alive",
#  'The Grey',
#  'Conan Ep.40',
#  'T2 Trainspotting',
#  'Anomalisa',
#  'Same Kind of Different as Me',
#  'Faster',
#  'Detachment',
#  'Collateral Beauty',
#  'Fantastic Mr. Fox',
#  'Dirty Weekend',
#  'Knights of Badassdom',
#  'Life of Pi',
#  'Addams Family Values',
#  'Jackass Presents: Bad Grandpa',
#  'Coach Carter',
#  'Superbad',
#  'The Devil Wears Prada',
#  "Tom And Jerry: anta's Little Helpers",
#  'Goosebumps',
#  'Click',
#  'Shrek The Third',
#  'Hareport',
#  'Kingsman: The ecret ervice',
#  'The Boxtrolls',
#  'The One I Love',
#  'Police tory',
#  'Little Fockers',
#  'Crazy Kind of Love',
#  'Seven Pounds',
#  'Madagascar: Escape Africa',
#  'The Da Vinci Code',
#  'Seventh on',
#  'Ana Wa Baba Wa Mama',
#  'Seabiscuit',
#  'G-Force',
#  "Ocean's Eleven",
#  'Adham Alsharqawy',
#  'The Terminal',
#  'Easy A',
#  'The ecret Life of Walter Mitty',
#  'White Chicks',
#  'Jack Reed: Death and Vengeance',
#  'The Cell',
#  'The Nut Job : Nutty by Nature',
#  'The Marine : Moving Target',
#  'The Princess Diaries',
#  'Mechanic: Resurrection',
#  "Kill'em All",
#  'Saad Wa Khawateh (T)',
#  'Hanna',
#  'Pearl Harbor',
#  'I Robot',
#  'Third tar',
#  'A Beautiful Mind',
#  'Little avages',
#  'A Few Good Men',
#  'Jonah Hex',
#  'The Alamo',
#  'Lilo and titch',
#  'Gutshot traight',
#  'Harry Potter and the Goblet of Fire under...',
#  'How to Lose a Guy in Days',
#  'Not Forgotten',
#  'Taboo',
#  'The House',
#  'Avatar',
#  'Flypaper',
#  'Raze',
#  'Fun with Dick and Jane',
#  'Fred Claus',
#  'Lion',
#  'Captain Majid Ep',
#  'Wrath of the Titans',
#  'The Eagle',
#  'Kingsman: The Golden Circle',
#  'A Fighting Man',
#  'Free Willy',
#  'Shanghai Knights',
#  'Ultimate Airport Dubai',
#  'Al-Gayyada (T)',
#  'Lulu and Marmar',
#  "King Arthur's Disasters",
#  'Die Hard: With a Vengeance',
#  'The tone Council',
#  'Concussion',
#  'Walk of Fame',
#  'Hidden Figures',
#  'Newsies: the Broadway Musical',
#  'Breaking Bad (T)',
#  'Inherent Vice',
#  'Starship Troopers: Traitor of Mars',
#  'The Last ong',
#  'Rugrats in Paris: The Movie',
#  'Watchmen',
#  'A unday Kind of Love',
#  'Chuggington',
#  'Allo Marhaba',
#  'Bad Ass',
#  'Batman: Assault on Arkham',
#  'Raiders of the Lost Ark',
#  'TRON: Legacy',
#  'Free Ride',
#  'You Got erved',
#  'Arthur Christmas',
#  'Ehna Al Talaba (T)',
#  'Superman IV: The Quest for Peace',
#  'Morning tar',
#  "The Devil's Hand",
#  'Justice League Adventures: Trapped In Time',
#  'P-51 Dragon Fighter',
#  'Inconceivable',
#  'John Wick: Chapter',
#  'The Expendables',
#  'Nan and Lili',
#  'The Road To El Dorado',
#  'AVP: Alien vs. Predator',
#  'Borj Al Oloum',
#  'Hannibal',
#  'A Royal Night Out',
#  'The Game of Their Lives',
#  "World's Best Chefs",
#  'Monster House',
#  'The Way Way Back',
#  'The Longest Ride',
#  'The -Year-Old Man Who Climbed Out',
#  'Super',
#  'Tom and Jerry: The Lost Dragon',
#  'The Possession Experiment',
#  'Agents of .H.I.E.L.D.',
#  'Everything Everything',
#  'Key & Peele',
#  'Killer Kids',
#  'Any Day',
#  'Trading Places',
#  'The Last King of cotland',
#  'Freelancers',
#  'Criminal Minds',
#  'Hawari Bokharist',
#  'The Founder',
#  'The earch',
#  'Water for Elephants',
#  'Their Finest',
#  'The Box',
#  'Lottery Ticket',
#  'The Chair',
#  'Aladdin',
#  "Charlie's Angels",
#  "The Hunter's Prayer",
#  'Road Trip',
#  'Appleseed Alpha',
#  'Pirates of The Caribbean: The Curse of…',
#  'Bee Movie',
#  'Mike The Knight',
#  'The Three tooges',
#  'Star Wars: The Last Jedi',
#  'Dalaa Banat (T)',
#  'Rumor Has It',
#  'Batman and Harley Quinn',
#  'Bates Motel',
#  'The econd Best Exotic Marigold Hotel',
#  'The Untouchables',
#  'Fences',
#  'Jumanji: Welcome to the Jungle',
#  'Puerto Ricans in Paris',
#  'Moneyball',
#  'E-Dounia Maqlouba',
#  'Me Myself & Irene',
#  'Mission Kathmandu',
#  'The Dressmaker',
#  'Lara Croft: Tomb Raider',
#  'Ghosts of Girlfriends Past',
#  'The Ugly Truth',
#  'Friday The th - Part II',
#  'Transfiguration',
#  'Atlanta',
#  'Inkheart',
#  'My Little Pony: Friendship Is Magic (T)',
#  'Lego DC Comics uper Heroes: The Flash',
#  'Mrs. Doubtfire',
#  'The Omen',
#  'Littlest Pet hop (T)',
#  'X-Men: The Last tand',
#  'Hebr El-Eyoun Ep.32',
#  'Boyz n the Hood',
#  'Stag Night',
#  'Beauty and the Beast',
#  '127 Hours',
#  'Transformers: Dark of the Moon',
#  'Planes: Fire and Rescue',
#  'Proof of Life',
#  'Buddymoon',
#  'Stuart Little',
#  'Pompeii',
#  'Isle of the Dead',
#  'Here Comes The Boom',
#  'World War Z',
#  'Save Your Legs!',
#  'Mission to Mars',
#  'Marley and Me: The Puppy Years',
#  'The Reaping',
#  'The ocial Network',
#  'Cloverfield',
#  'Max Payne',
#  'Farq Tawqeet',
#  'How to Train Your Dragon',
#  'Nightcrawler',
#  'Mike and Dave Need Wedding Dates',
#  'A Walk Among the Tombstones',
#  'Blood of Redemption',
#  'Rush Hour',
#  'The Girl with the Dragon Tattoo',
#  'Chronicle',
#  'Panic Room',
#  'Guardians Of The Tomb',
#  'Machete',
#  'Six Days even Nights',
#  'Paranormal Activity',
#  'Timer',
#  'Sherlock Holmes',
#  'Wayward Pines',
#  'Sister Act : Back in the Habit',
#  '10 Days in a Madhouse',
#  'Northmen - A Viking aga',
#  'Geostorm',
#  'Fargo',
#  'Muppets Most Wanted',
#  'Con Air',
#  'He Was a Quiet Man',
#  'Shutter',
#  'The Tuxedo',
#  'Rebel in the Rye',
#  'Taxi',
#  'Jurassic Park III',
#  'Cold Play',
#  'Catch Me If You Can',
#  'The Whole Wide World',
#  'The Man With The Iron Fists',
#  'Kingdom of Heaven',
#  'Batman vs Robin',
#  'Bayna Laylatin Wa Dohaha',
#  'Free Willy : The Rescue',
#  'Independence Day: th Anniversary Edition',
#  '24 Carat (T)',
#  'Hunt for the Wilderpeople',
#  'Margot at the Wedding',
#  'Arbitrage',
#  'Ronaldo',
#  'The Monuments Men',
#  'Batman Unlimited: Animal Instincts (for Viewing)',
#  '#FollowFriday',
#  "Shoot 'Em Up",
#  'Billy Elliot the Musical Live',
#  "That's My Boy",
#  "The orcerer's Apprentice",
#  'Freeway',
#  "Gangsters: America's Most Evil",
#  'Harry Potter - Part',
#  'Seeking Justice',
#  '101 Dalmatians',
#  'Saw',
#  'Life As We Know It',
#  ...]

# %% [markdown]
# problem: in STC JAWWY dataset, it seemed that we do not have enough information about the content (movies and tv shows information) such as year release, overview, genres,  ratings, and votes. these variables are important to build content-based recommendation system. the goal is to give the engine a name of a movie the user watched and show a list of simialr movies based content of seen movies. ex, if I watched Avengers, I should get movies about superheros and stuff!
#
# in our case with STC dataset, we do not have unique id for each movie and tv show in. order to get more data about our movies and tvs

# %% [markdown]
# ## Find STC JAWWY Movies and TV Shows in tmbd API

# %%
def get_tmdb_id(names, types):
    """ function to get IDs of external movies and TV shows list from tmdb
    input
    names: list of item names (TV shows, Movies)
    
    output: 
    item_api_id; a list of all found IDs for target item names
    item_name_not_found: a list of all not found name for target item names
    item_dic: full details info about target item names from API
    
    """
    item_api_id = []
    item_name_not_found = []
    item_dic = []
    for name in names:
        search  = types.search(name) # search api for names
        
        if len(search) != 0: # if nothing, meand we do not have the name in tmdb
            search = search[0]
            item_dic.append(search) # add found items in list
            item_api_id.append(search.id)
        else:
            item_name_not_found.append(name)
    # return 3 
    return item_api_id, item_name_not_found, item_dic

# %%
movie_api_id, movie_name_not_found, movie_dic = get_tmdb_id(movie_orig, movie)
tv_api_id, tv_name_not_found, tv_dic = get_tmdb_id(tv_orig, tv)

# %%
# get all the genres ids list from tmdb
genres_tv = genre.tv_list()
genres_movie = genre.movie_list()
genres_tv.extend(genres_movie)
all_genres = genres_tv

# %%
print("TV Shows in STC JAWWY     {}".format(len(tv_orig)))
print("TV Shows ID Found in TMDB {}".format(len(tv_api_id)))
print("TV Shows ID Not Found     {}".format(len(tv_name_not_found)))
print()
print("Movies in STC JAWWY       {}".format(len(movie_orig)))
print("Movies ID Found in TMDB   {}".format(len(movie_api_id)))
print("Movies ID Not Found       {}".format(len(movie_name_not_found)))
# Out:
# TV Shows in STC JAWWY     276
# TV Shows ID Found in TMDB 134
# TV Shows ID Not Found     142
#
# Movies in STC JAWWY       1525
# Movies ID Found in TMDB   1330
# Movies ID Not Found       195

# %% [markdown]
# ## Save dictionary of movies and tv shows to CSV

# %%
def export_list_dic(dic, filename):
    import csv
    csv_columns = list(dic[0].keys())
    dict_data = dic
    csv_file = "{}.csv".format(filename)
    try:
        with open(csv_file, 'w') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
            writer.writeheader()
            for data in dict_data:
                writer.writerow(data)
    except IOError:
        print("I/O error")

# %%
export_list_dic(tv_dic, 'tv_df')
export_list_dic(movie_dic, 'movie_df')
export_list_dic(all_genres, 'genre_df')

# %% [markdown]
# ## It seems that we less than 50% find in TV shows from TMDB and almot 80% of Movies found in TMDB API.
# ## Something to note that JAWWY has Arabic movies and TV shows and we can assume some of them are not in TMDB. Also, typos can be another issue here where we can not search a typo in TMDB and it has to be correct original name of content.

# %%
# load dfs
movie_df = pd.read_csv('movie_df.csv')
tv_df    = pd.read_csv('tv_df.csv')
genre_df  = pd.read_csv('genre_df.csv')
genre_df  = genre_df.drop_duplicates()

# %%
tv_df.head(2)
# Out:
#                       backdrop_path first_air_date genre_ids     id     name  \
# 0  /btmQDXFn72Q4yJcnewEt1pkFPer.jpg     2016-08-23        []  89385  سيرة حب
# 1  /1daNZnQmn3UOWGjsv18d4q0CUUd.jpg     2017-11-05  [35, 18]  71733    SMILF
#
#   origin_country original_language original_name  \
# 0             []                ar       سيرة حب
# 1         ['US']                en         SMILF
#
#                                             overview  popularity  \
# 0                                                NaN       0.600
# 1  A raw and honest comedic look at a single, 20-...      15.212
#
#                         poster_path  vote_average  vote_count
# 0  /5ePW12jO3qy5rTKh3x8UhEhmPrF.jpg           0.0           0
# 1  /yrHVP3NQgvMwGhjcA9W49P7uE4O.jpg           6.2          36

# %%
# add a type in the dict
movie_df['program_type'] = 'Movie'
tv_df['program_type'] = 'TV Show'

# %% [markdown]
# ### if we notice in the genre_ids column, we have a genre ids list that are a referrence to genres API. We will perform a convertions from these list into the real genre names for movies and tv shows

# %%
tv_df
# Out:
#                         backdrop_path first_air_date           genre_ids  \
# 0    /btmQDXFn72Q4yJcnewEt1pkFPer.jpg     2016-08-23                  []
# 1    /1daNZnQmn3UOWGjsv18d4q0CUUd.jpg     2017-11-05            [35, 18]
# 2    /z1ozzJ7AFvyMoYFKZhCblUzISX1.jpg     2008-11-28            [16, 35]
# 3    /oYnQ8dnj0uCpa4OotxlKLDh5BrB.jpg     2015-04-05                [18]
# 4    /dQLpDcHFMbVV33cRxJcnrCKsuWt.jpg     2018-01-18  [18, 10765, 10759]
# ..                                ...            ...                 ...
# 129  /s3pypVJf05ELPCUA6jSW381nLwm.jpg     2013-03-18      [18, 80, 9648]
# 130  /v2b4GxILejrDk8Y0WLzTZqkM39Z.jpg     2007-03-19             [10762]
# 131                               NaN     2007-09-22     [16, 35, 10759]
# 132  /r1e0lDIsezrklektX82AetUHr5m.jpg     2017-02-08      [10759, 10765]
# 133  /5BMwFwNzSidVYArn561acqtktxv.jpg     2005-09-19                [35]
#
#         id                        name origin_country original_language  \
# 0    89385                     سيرة حب             []                ar
# 1    71733                       SMILF         ['US']                en
# 2     7869  The Penguins of Madagascar         ['US']                en
# 3    61702            American Odyssey         ['US']                en
# 4    70484                   Britannia         ['GB']                en
# ..     ...                         ...            ...               ...
# 129  46786                 Bates Motel         ['US']                en
# 130   3048         In the Night Garden         ['GB']                en
# 131  15288                   Skunk Fu!   ['AU', 'GB']                en
# 132  67195                      Legion         ['US']                en
# 133   1100       How I Met Your Mother         ['US']                en
#
#                   original_name  \
# 0                       سيرة حب
# 1                         SMILF
# 2    The Penguins of Madagascar
# 3              American Odyssey
# 4                     Britannia
# ..                          ...
# 129                 Bates Motel
# 130         In the Night Garden
# 131                   Skunk Fu!
# 132                      Legion
# 133       How I Met Your Mother
#
#                                               overview  popularity  \
# 0                                                  NaN       0.600
# 1    A raw and honest comedic look at a single, 20-...      15.212
# 2    The Penguins of Madagascar is an American CGI ...      82.180
# 3    In this "Traffic"-like action drama, an intern...      10.438
# 4    An epic drama set in 43AD as the Roman Imperia...      47.403
# ..                                                 ...         ...
# 129  A "contemporary prequel" to the 1960 film Psyc...      88.480
# 130  In the Night Garden is a magical place that ex...      19.752
# 131  Skunk Fu! is an Irish animated children's tele...       1.236
# 132  David Haller, AKA Legion, is a troubled young ...      46.199
# 133  A father recounts to his children - through a ...     229.134
#
#                           poster_path  vote_average  vote_count program_type
# 0    /5ePW12jO3qy5rTKh3x8UhEhmPrF.jpg           0.0           0      TV Show
# 1    /yrHVP3NQgvMwGhjcA9W49P7uE4O.jpg           6.2          36      TV Show
# 2    /cke04QJGeSoZDgVZ1iSbgQ2QvYd.jpg           7.2         153      TV Show
# 3    /zCkrtf8QWK09Udnnso6mqnIKniz.jpg           7.3          34      TV Show
# 4    /fjdXymXAas9NSehc6GCOHQcEM05.jpg           6.9         125      TV Show
# ..                                ...           ...         ...          ...
# 129  /xXKcfZE7ulYxgjjYv51s0zDG69s.jpg           8.1        1189      TV Show
# 130  /qD5xsX8aPNYHATq6f28WVQslpqq.jpg           5.3           3      TV Show
# 131  /5GDbyMnT8O9tePXwEcCU9TsroMk.jpg           8.0           2      TV Show
# 132  /vT0Zsbm4GWd7llNjgWEtwY0CqOv.jpg           7.6        1045      TV Show
# 133  /dvxSvr6OmYGvvt8Z1VdBlPfL1Lf.jpg           8.2        3231      TV Show
#
# [134 rows x 14 columns]

# %%
def convert_string_list(df, column):
    """ convert dataframe colument that is quoted "list" into [list] class
    input:
    df: dataframe
    column: takes str of column name that need to be converted
    
    output: 
    df: converted values of target column from string-list to list
    """
    print('Before: {}, type: {}'.format(df[column][1], type(df[column][1])))
    
    for i in range(len(df[column])):
        df[column][i] = json.loads(df[column][i])
    
    print('After: {}, type: {}'.format(df[column][1], type(df[column][1])))

# %%
convert_string_list(movie_df, 'genre_ids')
convert_string_list(tv_df, 'genre_ids')
# Out:
# Before: [18, 53], type: <class 'str'>
# After: [18, 53], type: <class 'list'>
# Before: [35, 18], type: <class 'str'>
# After: [35, 18], type: <class 'list'>

# %%
def id_to_genre(df):
    """ convert ids of genre_ids primery key into actual values 
    
    input: dataframe with genre_ids column as [35,53,543]
    
    output: dataframe with genre_ids column as [action, comdey, horror]
    """
    print('Before: {}'.format(df['genre_ids'][1]))

    for i in range(len(df)):
        lists = df['genre_ids'][i]
        names = list(genre_df[genre_df['id'].isin(lists)]['name'])
        df.loc[:,'genre_ids'][i] = names
          
    print('After: {}'.format(df['genre_ids'][1]))

# %%
id_to_genre(tv_df)
id_to_genre(movie_df)
# Out:
# Before: [35, 18]
# After: ['Comedy', 'Drama']
# Before: [18, 53]
# After: ['Drama', 'Thriller']

# %% [markdown]
# ## Now We have have two dataframes that have enough data points for content recommendation
# ### we will concate movie_df and tv_df into one final df, and we can join the final df to our orginal dataframe (stc)

# %%
tv_df.head(2)
# Out:
#                       backdrop_path first_air_date        genre_ids     id  \
# 0  /btmQDXFn72Q4yJcnewEt1pkFPer.jpg     2016-08-23               []  89385
# 1  /1daNZnQmn3UOWGjsv18d4q0CUUd.jpg     2017-11-05  [Comedy, Drama]  71733
#
#       name origin_country original_language original_name  \
# 0  سيرة حب             []                ar       سيرة حب
# 1    SMILF         ['US']                en         SMILF
#
#                                             overview  popularity  \
# 0                                                NaN       0.600
# 1  A raw and honest comedic look at a single, 20-...      15.212
#
#                         poster_path  vote_average  vote_count program_type
# 0  /5ePW12jO3qy5rTKh3x8UhEhmPrF.jpg           0.0           0      TV Show
# 1  /yrHVP3NQgvMwGhjcA9W49P7uE4O.jpg           6.2          36      TV Show

# %%
tv_df.columns = ['backdrop_path', 'release_date', 'genre_ids', 'id', 'name',
       'origin_country', 'original_language', 'original_title', 'overview',
       'popularity', 'poster_path', 'vote_average', 'vote_count',
       'program_type']

# %%
column_needed = ['id', 'original_title','release_date','program_type', 'genre_ids', 'overview', 'popularity', 'vote_average', 'vote_count']

# %%
movie_df = movie_df[column_needed]
tv_df = tv_df[column_needed]

# %%
dfs = [movie_df, tv_df]
df  = pd.concat(dfs)
df  = df.reset_index()

# %%
df = df.drop('index', axis=1)

# %%
df.columns = ['id', 'original_title','release_date','program_type', 'genres', 'overview', 'popularity', 'vote_average', 'vote_count']

# %%
df
# Out:
#          id         original_title release_date program_type  \
# 0     73937           The Big Year   2011-10-13        Movie
# 1     55061        Frankie & Alice   2010-12-10        Movie
# 2     14560   Paul Blart: Mall Cop   2009-01-15        Movie
# 3      9499             Le Divorce   2003-08-08        Movie
# 4     27581         The Other Guys   2010-08-06        Movie
# ...     ...                    ...          ...          ...
# 1459  46786            Bates Motel   2013-03-18      TV Show
# 1460   3048    In the Night Garden   2007-03-19      TV Show
# 1461  15288              Skunk Fu!   2007-09-22      TV Show
# 1462  67195                 Legion   2017-02-08      TV Show
# 1463   1100  How I Met Your Mother   2005-09-19      TV Show
#
#                                        genres  \
# 0                                    [Comedy]
# 1                           [Drama, Thriller]
# 2         [Comedy, Family, Action, Adventure]
# 3                    [Comedy, Drama, Romance]
# 4                     [Comedy, Crime, Action]
# ...                                       ...
# 1459                  [Crime, Drama, Mystery]
# 1460                                   [Kids]
# 1461  [Action & Adventure, Animation, Comedy]
# 1462   [Action & Adventure, Sci-Fi & Fantasy]
# 1463                                 [Comedy]
#
#                                                overview  popularity  \
# 0     Three fanatical bird-watchers spend an entire ...      10.115
# 1     A drama centered on a go-go dancer with multip...       9.796
# 2     Mild-mannered Paul Blart has always had huge d...      46.979
# 3     While visiting her sister in Paris, a young wo...      13.596
# 4     Unlike their heroic counterparts on the force,...      56.626
# ...                                                 ...         ...
# 1459  A "contemporary prequel" to the 1960 film Psyc...      88.480
# 1460  In the Night Garden is a magical place that ex...      19.752
# 1461  Skunk Fu! is an Irish animated children's tele...       1.236
# 1462  David Haller, AKA Legion, is a troubled young ...      46.199
# 1463  A father recounts to his children - through a ...     229.134
#
#       vote_average  vote_count
# 0              6.0         612
# 1              5.8          71
# 2              5.4        2012
# 3              4.9         112
# 4              6.3        3315
# ...            ...         ...
# 1459           8.1        1189
# 1460           5.3           3
# 1461           8.0           2
# 1462           7.6        1045
# 1463           8.2        3231
#
# [1464 rows x 9 columns]

# %%
df['release_date'] = [str(x)[:4] for x in df['release_date']]

# %%
items  = list(df['original_title'].values)

# %%
stc1 = stc[stc['original_name'].isin(items)]
stc_working = stc[~stc['original_name'].isin(items)]

# %%
stc_working.shape
# Out:
# (2604412, 12)

# %%
stc_check = list(set(stc_working.original_name))

# %%
stc[stc['original_name'].isin(items)]
# Out:
#               date_  user_id_maped     program_name  duration_seconds  \
# 1        2017-05-21           7946           Moana                 17
# 4        2017-07-07          15860       Churchill                 87
# 7        2018-03-29           6358            Coco                 14
# 8        2018-01-27          11660          Kidnap                 85
# 9        2017-03-30           5155  The Accountant                 42
# ...             ...            ...              ...               ...
# 3598589  2017-07-23          12505    The Neighbor                 34
# 3598590  2018-03-08          12505   Mrs. Doubtfire                21
# 3598591  2017-07-16          12505          Trolls                  4
# 3598596  2017-08-22          10486        Snatched                  6
# 3598606  2017-10-30            717   Unforgettable                 95
#
#         program_class  season  episode                     program_desc  \
# 1               MOVIE       0        0        Animation MovieMoana (HD)
# 4               MOVIE       0        0    Biography MovieChurchill (HD)
# 7               MOVIE       0        0         Animation MovieCoco (HD)
# 8               MOVIE       0        0          Action MovieKidnap (HD)
# 9               MOVIE       0        0  Action MovieThe Accountant (HD)
# ...               ...     ...      ...                              ...
# 3598589         MOVIE       0        0    Horror MovieThe Neighbor (HD)
# 3598590         MOVIE       0        0       Comedy MovieMrs. Doubtfire
# 3598591         MOVIE       0        0       Animation MovieTrolls (HD)
# 3598596         MOVIE       0        0        Comedy MovieSnatched (HD)
# 3598606         MOVIE       0        0    Drama MovieUnforgettable (HD)
#
#         program_genre  series_title  hd   original_name
# 1           Animation             0   1           Moana
# 4           Biography             0   1       Churchill
# 7           Animation             0   1            Coco
# 8              Action             0   1          Kidnap
# 9              Action             0   1  The Accountant
# ...               ...           ...  ..             ...
# 3598589        Horror             0   1    The Neighbor
# 3598590        Comedy             0   0  Mrs. Doubtfire
# 3598591     Animation             0   1          Trolls
# 3598596        Comedy             0   1        Snatched
# 3598606         Drama             0   1   Unforgettable
#
# [994195 rows x 12 columns]

# %%
alls = list(set(stc['original_name']))

# %%
movie_api_id, movie_name_not_found, movie_dic = get_tmdb_id(alls, movie)
tv_api_id, tv_name_not_found, tv_dic = get_tmdb_id(alls, tv)

# %%
print("TV Shows in STC JAWWY     {}".format(len(tv_orig)))

print("TV Shows in STC JAWWY     {}".format(len(alls)))
print("TV Shows ID Found in TMDB {}".format(len(tv_api_id)))
print("TV Shows ID Not Found     {}".format(len(tv_name_not_found)))
print()

print("Movies in STC JAWWY     {}".format(len(movie_orig)))
print("Movies in STC JAWWY       {}".format(len(alls)))
print("Movies ID Found in TMDB   {}".format(len(movie_api_id)))
print("Movies ID Not Found       {}".format(len(movie_name_not_found)))
# Out:
# TV Shows in STC JAWWY     276
# TV Shows in STC JAWWY     1828
# TV Shows ID Found in TMDB 726
# TV Shows ID Not Found     1102
#
# Movies in STC JAWWY     1525
# Movies in STC JAWWY       1828
# Movies ID Found in TMDB   1452
# Movies ID Not Found       376

# %%
stc_working
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/sn/7klq0gls5qz987z3jr52_jym0000gn/T/ipykernel_3087/293302089.py in <module>
# ----> 1 stc_working
#
# NameError: name 'stc_working' is not defined
